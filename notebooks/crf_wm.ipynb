# %%
import pickle
import copy
import numpy as np
import sklearn
import scipy.stats
from sklearn.metrics import make_scorer
from sklearn.metrics import classification_report
# from sklearn.cross_validation import cross_val_score
# from sklearn.grid_search import RandomizedSearchCV

import sklearn_crfsuite
from sklearn_crfsuite import scorers
from sklearn_crfsuite import metrics

# %%
def get_sent_labels(token_list):
    sent_labels, sentences, sent_start = [], [], 0
    for i, line in enumerate(token_list):
        if line == '\n':
            sentences.append(sent_labels)
            sent_labels = []
        else:        
            token, label = line.rstrip().split()
            sent_labels.append(label)
    return sentences

def get_sent_tokens(token_list):
    sent_tokens, sentences, sent_start = [], [], 0
    for i, line in enumerate(token_list):
        if line == '\n':
            sentences.append(sent_tokens)
            sent_tokens = []
        else:        
            token, label = line.rstrip().split()
            sent_tokens.append(token)
    return sentences

def sent2features(sent_emb):
    features = []

    for word_emb in sent_emb:
        word_features = {}
        if len(word_emb.shape) > 0:
            for i in range(word_emb.shape[0]):
                word_features['bert_features_{}'.format(i)] = float(word_emb[i])
        else:
            word_features['bert_features_0'] = float(word_emb)
            
        features.append(copy.deepcopy(word_features))
        del word_features
    
    return features

def merge_features(bert_features, other_features):
    
    for sent_emb_features, sent_other_features in zip(bert_features, other_features):
        
        for word_emb_features, word_other_features in zip(sent_emb_features[:len(sent_other_features)], sent_other_features):
            word_other_features.update(word_emb_features)
        
        if len(sent_other_features) > len(sent_emb_features):
            for _ in range(len(sent_other_features)-len(sent_emb_features)):
                sent_other_features.pop()

# %% [markdown]
# # BERT features

# %%
wm1 = open('../../data_wm/arg_clean_45_1/test.txt','r').readlines()
wm1_labels = get_sent_labels(wm1)
wm1_features = pickle.load(open('../features/wm1_emb.p','rb'))
print(len(wm1_features), len(wm1_labels))

wm2 = open('../../data_wm/arg_clean_45_2/train.txt','r').readlines()
wm2_labels = get_sent_labels(wm2)
wm2_features = pickle.load(open('../features/wm2_emb.p','rb'))
print(len(wm2_features), len(wm2_labels))

wm_nr = open('../../data_wm/wm_narrative/test.txt','r').readlines()
wm_nr_labels = get_sent_labels(wm_nr)

wm_nr_features = pickle.load(open('../features/wm_nr_emb.p','rb'))
print(len(wm_nr_features), len(wm_nr_labels))
# Out:
# 1266 1266
# 1862 1862
# 1332 1332

# %%
wm1_tokens = get_sent_tokens(wm1)
wm2_tokens = get_sent_tokens(wm2)
wm_nr_tokens = get_sent_tokens(wm_nr)

# %%
# bert embeddings only
crf = sklearn_crfsuite.CRF(algorithm='lbfgs', c1=0.1, c2=0.1, max_iterations=100, all_possible_transitions=True)
crf.fit(wm2_features, wm2_labels)

y_pred = crf.predict(wm1_features)
y_test_flat = [y for y_seq in wm1_labels for y in y_seq]
y_pred_flat = [y for y_seq in y_pred for y in y_seq]
print(classification_report(y_test_flat, y_pred_flat, digits=3))

y_pred = crf.predict(wm_nr_features)
y_test_flat = [y for y_seq in wm_nr_labels for y in y_seq]
y_pred_flat = [y for y_seq in y_pred for y in y_seq]
print(classification_report(y_test_flat, y_pred_flat, digits=3))
# Out:
#               precision    recall  f1-score   support
#
#      B-claim      0.527     0.291     0.375       707
#      I-claim      0.662     0.432     0.523      7407
#      O-claim      0.768     0.900     0.829     16841
#
#     accuracy                          0.744     24955
#    macro avg      0.652     0.541     0.576     24955
# weighted avg      0.730     0.744     0.725     24955
#
#               precision    recall  f1-score   support
#
#      B-claim      0.053     0.270     0.089        37
#      I-claim      0.092     0.426     0.151       350
#      O-claim      0.989     0.923     0.955     21465
#
#     accuracy                          0.914     21852
#    macro avg      0.378     0.540     0.398     21852
# weighted avg      0.973     0.914     0.941     21852

# %%
# bert embeddings only
crf = sklearn_crfsuite.CRF(algorithm='lbfgs', c1=0.1, c2=0.1, max_iterations=1000, all_possible_transitions=True)
crf.fit(wm2_features, wm2_labels)

y_pred = crf.predict(wm1_features)
y_test_flat = [y for y_seq in wm1_labels for y in y_seq]
y_pred_flat = [y for y_seq in y_pred for y in y_seq]
print(classification_report(y_test_flat, y_pred_flat, digits=3))

y_pred = crf.predict(wm_nr_features)
y_test_flat = [y for y_seq in wm_nr_labels for y in y_seq]
y_pred_flat = [y for y_seq in y_pred for y in y_seq]
print(classification_report(y_test_flat, y_pred_flat, digits=3))
# Out:
#               precision    recall  f1-score   support
#
#      B-claim      0.475     0.327     0.387       707
#      I-claim      0.603     0.473     0.530      7407
#      O-claim      0.773     0.856     0.812     16841
#
#     accuracy                          0.728     24955
#    macro avg      0.617     0.552     0.577     24955
# weighted avg      0.714     0.728     0.717     24955
#
#               precision    recall  f1-score   support
#
#      B-claim      0.052     0.324     0.090        37
#      I-claim      0.089     0.511     0.152       350
#      O-claim      0.990     0.905     0.946     21465
#
#     accuracy                          0.898     21852
#    macro avg      0.377     0.580     0.396     21852
# weighted avg      0.974     0.898     0.931     21852

# %%
# bert embeddings only
crf = sklearn_crfsuite.CRF(algorithm='l2sgd', c2=0.1, max_iterations=1000, all_possible_transitions=True)
crf.fit(wm2_features, wm2_labels)

y_pred = crf.predict(wm1_features)
y_test_flat = [y for y_seq in wm1_labels for y in y_seq]
y_pred_flat = [y for y_seq in y_pred for y in y_seq]
print(classification_report(y_test_flat, y_pred_flat, digits=3))

y_pred = crf.predict(wm_nr_features)
y_test_flat = [y for y_seq in wm_nr_labels for y in y_seq]
y_pred_flat = [y for y_seq in y_pred for y in y_seq]
print(classification_report(y_test_flat, y_pred_flat, digits=3))
# Out:
#               precision    recall  f1-score   support
#
#      B-claim      0.495     0.355     0.414       707
#      I-claim      0.648     0.529     0.582      7407
#      O-claim      0.794     0.868     0.830     16841
#
#     accuracy                          0.753     24955
#    macro avg      0.646     0.584     0.608     24955
# weighted avg      0.742     0.753     0.744     24955
#
#               precision    recall  f1-score   support
#
#      B-claim      0.057     0.324     0.096        37
#      I-claim      0.112     0.580     0.188       350
#      O-claim      0.992     0.916     0.952     21465
#
#     accuracy                          0.910     21852
#    macro avg      0.387     0.607     0.412     21852
# weighted avg      0.976     0.910     0.939     21852

# %% [markdown]
# # LexSyn

# %%
wm1_lexsyn = pickle.load(open('../features/wm1_lexsyn.p','rb'))
wm2_lexsyn = pickle.load(open('../features/wm2_lexsyn.p','rb'))
wm_nr_lexsyn = pickle.load(open('../features/wm_nr_lexsyn.p','rb'))

# %%
# LexSyn only
# crf = sklearn_crfsuite.CRF(algorithm='lbfgs', c1=0.1, c2=0.1, max_iterations=100, all_possible_transitions=True)
crf = sklearn_crfsuite.CRF(algorithm='l2sgd', c2=0.1, max_iterations=1000, all_possible_transitions=True)
crf.fit(wm2_lexsyn, wm2_labels)

y_pred = crf.predict(wm1_lexsyn)
y_test_flat = [y for y_seq in wm1_labels for y in y_seq]
y_pred_flat = [y for y_seq in y_pred for y in y_seq]
print(classification_report(y_test_flat, y_pred_flat, digits=3))

y_pred = crf.predict(wm_nr_lexsyn)
y_test_flat = [y for y_seq in wm_nr_labels for y in y_seq]
y_pred_flat = [y for y_seq in y_pred for y in y_seq]
print(classification_report(y_test_flat, y_pred_flat, digits=3))
# Out:
#               precision    recall  f1-score   support
#
#      B-claim      0.584     0.301     0.397       707
#      I-claim      0.703     0.379     0.493      7407
#      O-claim      0.757     0.926     0.833     16841
#
#     accuracy                          0.746     24955
#    macro avg      0.681     0.535     0.574     24955
# weighted avg      0.736     0.746     0.720     24955
#
#               precision    recall  f1-score   support
#
#      B-claim      0.057     0.243     0.092        37
#      I-claim      0.095     0.406     0.154       350
#      O-claim      0.989     0.931     0.959     21465
#
#     accuracy                          0.921     21852
#    macro avg      0.380     0.526     0.402     21852
# weighted avg      0.973     0.921     0.944     21852

# %% [markdown]
# # BERT + LexSyn features

# %%
# x_lexsyn has both lexsyn and bert features after using merge
merge_features(wm1_features, wm1_lexsyn)
merge_features(wm2_features, wm2_lexsyn)
merge_features(wm_nr_features, wm_nr_lexsyn)

# %%
crf = sklearn_crfsuite.CRF(algorithm='lbfgs', c1=0.1, c2=0.1, max_iterations=100, all_possible_transitions=True)
# crf = sklearn_crfsuite.CRF(algorithm='l2sgd', c2=0.1, max_iterations=1000, all_possible_transitions=True)
crf.fit(wm2_lexsyn, wm2_labels)

y_pred = crf.predict(wm1_lexsyn)
y_test_flat = [y for y_seq in wm1_labels for y in y_seq]
y_pred_flat = [y for y_seq in y_pred for y in y_seq]
print(classification_report(y_test_flat, y_pred_flat, digits=3))

y_pred = crf.predict(wm_nr_lexsyn)
y_test_flat = [y for y_seq in wm_nr_labels for y in y_seq]
y_pred_flat = [y for y_seq in y_pred for y in y_seq]
print(classification_report(y_test_flat, y_pred_flat, digits=3))
# Out:
#               precision    recall  f1-score   support
#
#      B-claim      0.572     0.337     0.424       707
#      I-claim      0.718     0.478     0.574      7407
#      O-claim      0.785     0.914     0.845     16841
#
#     accuracy                          0.768     24955
#    macro avg      0.692     0.576     0.614     24955
# weighted avg      0.759     0.768     0.752     24955
#
#               precision    recall  f1-score   support
#
#      B-claim      0.050     0.216     0.082        37
#      I-claim      0.117     0.494     0.189       350
#      O-claim      0.990     0.932     0.960     21465
#
#     accuracy                          0.924     21852
#    macro avg      0.386     0.548     0.410     21852
# weighted avg      0.975     0.924     0.947     21852

# %% [markdown]
# # All Discrete Features

# %%
wm1_all = pickle.load(open('../features/wm1_all.p','rb'))
wm2_all = pickle.load(open('../features/wm2_all.p','rb'))
wm_nr_all = pickle.load(open('../features/wm_nr_all.p','rb'))

# %%
crf = sklearn_crfsuite.CRF(algorithm='lbfgs', c1=0.1, c2=0.1, max_iterations=100, all_possible_transitions=True)
# crf = sklearn_crfsuite.CRF(algorithm='l2sgd', c2=0.1, max_iterations=1000, all_possible_transitions=True)
crf.fit(wm2_all, wm2_labels)

y_pred = crf.predict(wm1_all)
y_test_flat = [y for y_seq in wm1_labels for y in y_seq]
y_pred_flat = [y for y_seq in y_pred for y in y_seq]
print(classification_report(y_test_flat, y_pred_flat, digits=3))
# Out:
#               precision    recall  f1-score   support
#
#      B-claim      0.433     0.465     0.449       707
#      I-claim      0.552     0.674     0.607      7407
#      O-claim      0.829     0.745     0.785     16841
#
#     accuracy                          0.716     24955
#    macro avg      0.605     0.628     0.614     24955
# weighted avg      0.735     0.716     0.722     24955

# %%
y_pred = crf.predict(wm2_all)
y_test_flat = [y for y_seq in wm2_labels for y in y_seq]
y_pred_flat = [y for y_seq in y_pred for y in y_seq]
print(classification_report(y_test_flat, y_pred_flat, digits=3))
# Out:
#               precision    recall  f1-score   support
#
#      B-claim      0.523     0.587     0.553       951
#      I-claim      0.636     0.772     0.697     10263
#      O-claim      0.891     0.809     0.848     25332
#
#     accuracy                          0.793     36546
#    macro avg      0.683     0.723     0.700     36546
# weighted avg      0.810     0.793     0.798     36546

# %%
crf = sklearn_crfsuite.CRF(algorithm='lbfgs', c1=0.1, c2=0.1, max_iterations=100, all_possible_transitions=True)
# crf = sklearn_crfsuite.CRF(algorithm='l2sgd', c2=0.1, max_iterations=1000, all_possible_transitions=True)
crf.fit(wm2_all, wm2_labels)

y_pred = crf.predict(wm1_all)
y_test_flat = [y for y_seq in wm1_labels for y in y_seq]
y_pred_flat = [y for y_seq in y_pred for y in y_seq]
print(classification_report(y_test_flat, y_pred_flat, digits=3))

y_pred = crf.predict(wm_nr_all)
y_test_flat = [y for y_seq in wm_nr_labels for y in y_seq]
y_pred_flat = [y for y_seq in y_pred for y in y_seq]
print(classification_report(y_test_flat, y_pred_flat, digits=3))
# Out:
#               precision    recall  f1-score   support
#
#      B-claim      0.433     0.465     0.449       707
#      I-claim      0.552     0.674     0.607      7407
#      O-claim      0.829     0.745     0.785     16841
#
#     accuracy                          0.716     24955
#    macro avg      0.605     0.628     0.614     24955
# weighted avg      0.735     0.716     0.722     24955
#
#               precision    recall  f1-score   support
#
#      B-claim      0.048     0.378     0.085        37
#      I-claim      0.067     0.523     0.120       350
#      O-claim      0.990     0.870     0.926     21465
#
#     accuracy                          0.863     21852
#    macro avg      0.369     0.590     0.377     21852
# weighted avg      0.974     0.863     0.912     21852

# %% [markdown]
# # All Discrete + BERT

# %%
# x_all has both all and bert features after using merge
merge_features(wm1_features, wm1_all)
merge_features(wm2_features, wm2_all)
merge_features(wm_nr_features, wm_nr_all)

# %%
crf = sklearn_crfsuite.CRF(algorithm='lbfgs', c1=0.1, c2=0.1, max_iterations=100, all_possible_transitions=True)
# crf = sklearn_crfsuite.CRF(algorithm='l2sgd', c2=0.1, max_iterations=1000, all_possible_transitions=True)
crf.fit(wm2_all, wm2_labels)

y_pred = crf.predict(wm1_all)
y_test_flat = [y for y_seq in wm1_labels for y in y_seq]
y_pred_flat = [y for y_seq in y_pred for y in y_seq]
print(classification_report(y_test_flat, y_pred_flat, digits=3))

y_pred = crf.predict(wm_nr_all)
y_test_flat = [y for y_seq in wm_nr_labels for y in y_seq]
y_pred_flat = [y for y_seq in y_pred for y in y_seq]
print(classification_report(y_test_flat, y_pred_flat, digits=3))
# Out:
#               precision    recall  f1-score   support
#
#      B-claim      0.475     0.437     0.455       707
#      I-claim      0.585     0.661     0.621      7407
#      O-claim      0.828     0.783     0.805     16841
#
#     accuracy                          0.737     24955
#    macro avg      0.629     0.627     0.627     24955
# weighted avg      0.746     0.737     0.741     24955
#
#               precision    recall  f1-score   support
#
#      B-claim      0.038     0.189     0.064        37
#      I-claim      0.074     0.440     0.126       350
#      O-claim      0.989     0.902     0.943     21465
#
#     accuracy                          0.893     21852
#    macro avg      0.367     0.510     0.378     21852
# weighted avg      0.973     0.893     0.929     21852

# %%
y_pred = crf.predict(wm1_all)
y_test_flat = [y for y_seq in wm1_labels for y in y_seq]
y_pred_flat = [y for y_seq in y_pred for y in y_seq]

# %%
for i, (tokens, labels, preds) in enumerate(zip(wm1_tokens[:100], wm1_labels[:100],y_pred[:100])):
    print(i+1)
    print(tokens)
    print(labels)
    print(preds)
    print()
# Out:
# 1
# ['Sharks', 'are', 'Not', 'the', 'Problem']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
#
# 2
# ['You', 'know', 'what', 'I', "'", 'm', 'talking', 'about', ',', 'the', 'large', 'fish', 'that', 'can', 'kill', 'you', 'with', 'one', 'advance', 'at', 'your', 'limbs', '.']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
#
# 3
# ['One', 'of', 'many', 'things', 'lurking', 'in', 'the', 'unknown', 'waters', 'of', 'the', 'ocean', 'ready', 'for', 'the', 'amazing', 'taste', 'of', 'your', 'blood', '.']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
#
# 4
# ['Well', 'if', 'that', "'s", 'what', 'someone', 'is', 'thinking', 'then', 'they', 'better', 'scrap', 'those', 'ideas', 'because', 'I', "'", 'm', 'going', 'to', 'explain', 'to', 'you', 'why', 'sharks', 'are', "n't", 'the', 'problem', '.']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'B-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim']
# ['O-claim', 'B-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
#
# 5
# ['Sharks', 'are', "n't", 'monsters', ',', 'in', 'reality', ',', 'they', 'are', 'very', 'special', 'animals', ',', 'what', 'I', 'mean', 'by', 'that', 'is', 'getting', 'rid', 'of', 'them', 'could', 'cause', 'the', 'whole', 'oceans', 'food', 'chain', 'to', 'collapse', '.']
# ['B-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'B-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'B-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim']
# ['B-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'B-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim']
#
# 6
# ['Many', 'species', 'would', 'be', 'affected', ',', 'many', 'species', 'would', 'end', 'just', 'because', 'of', 'the', 'sharks', '.']
# ['B-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim', 'B-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim']
# ['B-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim', 'B-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim']
#
# 7
# ['A', 'number', 'of', 'scientific', 'studies', 'demonstrate', 'that', 'depletion', 'of', 'sharks', 'results', 'in', 'the', 'loss', 'of', 'commercially', 'important', 'fish', 'and', 'shellfish', 'species', 'down', 'the', 'food', 'chain', ',', 'including', 'key', 'fisheries', 'such', 'as', 'tuna', ',', 'that', 'maintain', 'the', 'health', 'of', 'coral', 'reefs', '.']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'B-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
#
# 8
# ['Adding', 'to', 'this', ',', 'predatory', 'sharks', 'prey', 'on', 'the', 'sick', '/', 'weak', 'members', 'of', 'fish', 'and', 'such', 'to', 'help', 'strengthen', 'the', 'population', '.']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
#
# 9
# ['Some', 'sharks', 'also', 'scavenge', 'the', 'seafloor', 'to', 'feed', 'on', 'dead', 'carcasses', '.']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
#
# 10
# ['Since', 'the', 'largest', ',', 'strongest', ',', 'and', 'healthiest', 'fish', 'generally', 'reproduce', 'in', 'greater', 'numbers', ',', 'the', 'outcome', 'is', 'larger', 'numbers', 'of', 'healthier', 'fish', '.']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'B-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim']
#
# 11
# ['Out', 'of', 'all', 'sharks', ',', 'only', 'about', 'a', 'dozen', 'are', 'dangerous', 'to', 'the', 'human', 'species', '.']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'B-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim']
#
# 12
# ['Moreover', ',', 'they', 'tend', 'to', 'not', 'attack', 'humans', 'that', 'often', ',', 'not', 'enough', 'to', 'earn', 'them', 'there', 'horrendous', 'stereotype', '.']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['O-claim', 'O-claim', 'B-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim']
#
# 13
# ['In', 'fact', ',', 'sharks', 'are', 'a', 'bigger', 'danger', 'to', 'themselves', 'than', 'to', 'any', 'human', '.']
# ['O-claim', 'O-claim', 'O-claim', 'B-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim']
# ['B-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim']
#
# 14
# ['Unborn', 'sand', 'tiger', ',', 'for', 'example', ',', 'are', 'known', 'to', 'feed', 'on', 'their', 'also', 'unborn', 'siblings', 'in', 'the', 'womb', '.']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'B-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim']
#
# 15
# ['Not', 'only', 'are', 'the', 'sharks', 'eating', 'their', 'fellow', 'brothers', "'", 'and', 'sisters', "'", 'bodies', ',', 'but', 'also', 'the', 'unfertilized', 'eggs', 'in', 'a', 'fit', 'of', 'embryonic', 'cannibalism', '.']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
#
# 16
# ['Take', 'the', 'most', 'feared', 'shark', 'of', 'them', 'all', ',', 'the', 'great', 'white', ':', 'From', '1926', '-', '2011', ',', 'great', 'whites', 'attacked', 'Americans', 'one', 'hundred', 'and', 'six', 'times', 'when', 'unprovoked', ',', 'and', 'only', 'thirteen', 'of', 'those', 'attacks', 'proved', 'fatal', '.']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['B-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
#
# 17
# ['Including', 'all', 'sharks', 'only', '1,055', 'attacks', 'were', 'unprovoked', 'in', 'America', 'with', 'the', 'exclusion', 'of', 'Hawaii', 'from', '1837', '-', '2013', ',', 'comprising', 'just', 'thirty', '-', 'six', 'fatal', 'attacks', '.']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
#
# 18
# ['Even', 'in', 'Hawaii', 'where', 'the', 'main', 'attractions', 'for', 'both', 'locals', 'and', 'tourists', 'is', 'the', 'ocean', ',', 'there', 'were', 'only', 'one', 'hundred', 'twenty', '-', 'nine', 'unprovoked', 'attacks', 'from', '1828', '-', '2013', ',', 'nine', 'of', 'which', 'were', 'fatal', '.']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
#
# 19
# ['Global', 'statistics', 'are', 'also', 'very', 'low', '.']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['B-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim']
#
# 20
# ['Annually', ',', 'around', '70', 'to', '100', 'shark', 'attacks', 'are', 'reported', 'around', 'the', 'world', ',', 'causing', 'just', 'about', '5', 'to', '15', 'deaths', '.']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
#
# 21
# ['Sharks', 'do', "n't", 'cause', 'as', 'many', 'deaths', 'as', 'you', 'think', ',', 'in', 'reality', ',', 'they', 'save', 'the', 'oceans', 'from', 'a', 'lot', 'of', 'disasters', '.']
# ['B-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'B-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'B-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim']
#
# 22
# ['Even', 'though', 'people', 'like', 'to', 'say', 'sharks', 'kill', 'millions', 'of', 'people', 'a', 'year', 'and', 'lower', 'the', 'populations', 'of', 'fish', 'they', 'are', 'wrong', '.']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'B-claim', 'I-claim', 'I-claim', 'O-claim']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
#
# 23
# ['Humans', 'need', 'to', 'understand', 'that', 'sharks', 'are', "n't", 'the', 'enemy', 'here', 'at', 'all', '.']
# ['B-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim']
# ['B-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim']
#
# 24
# ['Honestly', ',', 'humans', 'need', 'to', 'do', 'more', 'research', 'before', 'self', '-', 'diagnosing', 'things', '.']
# ['O-claim', 'O-claim', 'B-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim']
# ['O-claim', 'O-claim', 'B-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim']
#
# 25
# ['Why', 'we', 'need', 'to', 'stop', 'killing', 'sharks']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['O-claim', 'B-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim']
#
# 26
# ['About', 'one', 'million', 'sharks', 'are', 'killed', 'every', 'year', 'just', 'by', 'humans', '.']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
#
# 27
# ['There', 'are', 'different', 'types', 'of', 'sharks', 'but', 'some', 'are', 'rarer', 'than', 'others', '.']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'B-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim']
#
# 28
# ['Sharks', 'only', 'swim', 'in', 'saltwater', 'and', 'usually', 'down', 'deep', 'in', 'the', 'water', '.']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
#
# 29
# ['Some', 'sharks', 'can', 'be', 'trained', 'to', 'be', 'very', 'friendly', 'with', 'humans', 'just', 'like', 'dolphins', '.']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['B-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim']
#
# 30
# ['All', 'shark', 'killings', 'must', 'come', 'to', 'an', 'end', '.']
# ['B-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim']
# ['B-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim']
#
# 31
# ['There', 'are', 'way', 'too', 'many', 'sharks', 'being', 'killed', 'each', 'year', 'and', 'this', 'is', 'a', 'problem', '.']
# ['B-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'B-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim']
#
# 32
# ['The', 'article', 'How', 'Many', 'Sharks', 'Do', 'Humans', 'Kill', 'Per', 'Hour', 'says', ',', 'humans', 'kill', 'around', '100', 'million', 'sharks', 'each', 'year', '.']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
#
# 33
# ['However', ',', 'they', 'add', 'that', 'this', 'is', 'a', 'conservative', 'estimate', ',', 'and', 'the', 'true', 'number', 'could', 'be', 'as', 'high', 'as', '273', 'million', 'sharks', 'killed', 'annually', 'by', 'humans', '.']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'B-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim']
#
# 34
# ['There', 'are', 'only', '90', 'shark', 'attacks', 'on', 'humans', 'a', 'year', '.']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
#
# 35
# ['The', 'number', 'of', 'sharks', 'killed', 'by', 'humans', 'each', 'year', 'is', 'the', 'way', 'to', 'high', 'and', 'increasing', '.']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
#
# 36
# ['Humans', 'kill', 'sharks', 'so', 'they', 'can', 'skin', 'them', 'and', 'sell', 'them', 'as', 'food', '.']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'B-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim']
#
# 37
# ['In', 'Japan', ',', 'shark', 'fin', 'soup', 'is', 'a', 'delicacy', '.']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
#
# 38
# ['Many', 'sharks', 'have', 'been', 'killed', 'just', 'to', 'make', 'this', 'soup', '.']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['B-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim']
#
# 39
# ['To', 'make', 'this', 'soup', 'humans', 'hunt', 'sharks', 'by', 'using', 'a', 'practice', 'called', 'shark', 'finning', '.']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['B-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
#
# 40
# ['The', 'article', 'Smithsonian', 'Ocean', 'says', 'this', 'is', 'the', 'process', 'of', 'slicing', 'off', 'a', 'shark', "'s", 'fin', 'and', 'discarding', 'the', 'rest', 'of', 'the', 'still', '-', 'living', 'body', ',', 'often', 'by', 'dumping', 'it', 'back', 'into', 'the', 'ocean', '.']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
#
# 41
# ['It', 'seems', 'very', 'waist', 'full', 'to', 'kill', 'sharks', 'just', 'for', 'their', 'fins', 'and', 'then', 'to', 'throw', 'out', 'the', 'rest', 'of', 'the', 'shark', '.']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'B-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
#
# 42
# ['Many', 'humans', 'hunt', 'sharks', 'illegally', 'and', 'this', 'is', 'putting', 'many', 'shark', 'breeds', 'at', 'risk', 'of', 'extinction', '.']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['B-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim']
#
# 43
# ['The', 'article', 'says', 'In', 'a', 'moving', 'range', ',', 'the', 'researchers', 'were', 'able', 'to', 'calculate', 'that', 'between', '6.4', '%', 'and', '7.9', '%', 'of', 'sharks', 'of', 'all', 'species', 'are', 'killed', 'annually', '.']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
#
# 44
# ['To', 'put', 'that', 'range', 'in', 'perspective', ',', 'researchers', 'analyzed', 'life', 'data', 'from', '62', 'shark', 'species', 'and', 'found', 'that', 'only', '4.9', '%', 'of', 'sharks', 'can', 'be', 'killed', 'each', 'year', 'to', 'maintain', 'population', 'stability', '.']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
#
# 45
# ['Shark', 'fin', 'soup', 'is', 'so', 'popular', 'in', 'Japan', 'that', 'shark', 'hunters', 'can', 'make', 'a', 'lot', 'of', 'money', 'from', 'selling', 'the', 'sharks', 'fins', '.']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
#
# 46
# ['Many', 'hunters', 'will', 'illegally', 'practice', 'shark', 'finning', 'so', 'they', 'do', "n't", 'have', 'to', 'report', 'how', 'many', 'sharks', 'they', 'have', 'caught', '.']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
#
# 47
# ['This', 'way', 'they', 'can', 'sell', 'more', 'shark', 'fins', 'and', 'make', 'more', 'money', '.']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['B-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim']
#
# 48
# ['Many', 'people', 'do', "n't", 'worry', 'about', 'sharks', 'becoming', 'extinct', 'because', 'they', 'are', 'afraid', 'of', 'them', '.']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['O-claim', 'B-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
#
# 49
# ['However', 'sharks', 'do', 'not', 'hunt', 'humans', ',', 'they', 'would', 'much', 'rather', 'eat', 'fish', 'or', 'other', 'sea', 'animals', '.']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['O-claim', 'B-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim']
#
# 50
# ['The', 'amount', 'of', 'shark', 'attack', 'on', 'humans', 'is', 'much', 'less', 'than', 'the', 'number', 'of', 'sharks', 'that', 'are', 'killed', 'by', 'humans', 'each', 'year', '.']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
#
# 51
# ['Sharks', 'are', 'very', 'important', 'to', 'the', 'see', 'they', 'help', 'keep', 'the', 'fish', 'in', 'the', 'normal', 'population', '.']
# ['B-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
#
# 52
# ['One', 'way', 'to', 'help', 'protect', 'sharks', 'from', 'extinction', 'is', 'to', 'stop', 'the', 'illegal', 'hunting', 'of', 'sharks', '.']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['B-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim']
#
# 53
# ['If', 'the', 'illegal', 'hunting', 'of', 'sharks', 'does', 'not', 'stop', 'we', 'could', 'end', 'up', 'losing', 'some', 'of', 'our', 'shark', 'breeds', '.']
# ['O-claim', 'B-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim']
# ['O-claim', 'B-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim']
#
# 54
# ['Imagine', 'a', 'moment', ':', 'your', 'best', 'friend', 'is', 'in', 'a', 'deadly', 'situation', '.']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'B-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim']
#
# 55
# ['All', 'the', 'memories', 'with', 'them', 'rush', 'back', 'to', 'your', 'head', ';', 'speeding', 'at', '65', 'mph', 'on', 'the', 'roller', 'coaster', 'and', 'working', 'on', 'homework', 'together', 'at', '3', 'A.M', '.']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
#
# 56
# ['You', 'could', 'have', 'saved', 'them', ',', 'but', 'you', 'hold', 'back', 'and', 'that', 'special', 'person', 'passes', 'away', '.']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'B-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim']
#
# 57
# ['The', 'Seventh', 'Man', 'was', 'in', 'a', 'scenario', 'similar', 'to', 'this', '.']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['B-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim']
#
# 58
# ['The', 'Seventh', 'Man', "'s", 'best', 'friend', ',', 'K', ',', 'died', 'in', 'front', 'of', 'his', 'eyes', 'and', 'he', 'did', 'not', 'save', 'him', '.']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
#
# 59
# ['The', 'Seventh', 'man', 'should', 'not', 'forgive', 'himself', 'for', 'failing', 'to', 'save', 'his', 'best', 'friend', '/', 'neighbor', ',', 'which', 'led', 'to', 'lifelong', 'objective', 'guilt', 'for', 'The', 'Seventh', 'Man', '.']
# ['B-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim']
# ['B-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim']
#
# 60
# ['According', 'to', 'The', 'Key', 'To', 'Disaster', 'Survival', '?']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
#
# 61
# ['Shankar', 'Vedantam', 'claims', 'the', 'people', 'you', 'live', 'closest', 'to', 'will', 'help', 'you', 'more', 'than', 'anybody', 'else', '.']
# ['O-claim', 'O-claim', 'O-claim', 'B-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
#
# 62
# ['The', 'Seventh', 'Man', 'and', 'K', 'were', 'neighbors', '.']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
#
# 63
# ['They', 'went', 'out', 'for', 'a', 'walk', 'while', 'they', 'were', 'in', 'the', 'eye', 'of', 'the', 'storm', ',', 'which', 'is', 'the', 'most', 'peaceful', 'part', 'of', 'the', 'problem', '.']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
#
# 64
# ['The', 'Seventh', 'man', 'knew', 'that', 'the', 'storm', 'was', 'coming', ',', 'but', 'in', 'no', 'way', 'gave', 'K', 'a', 'proper', 'warning', '.']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
#
# 65
# ['In', 'Japan', ',', 'Aldrich', 'found', 'that', 'fire', 'trucks', 'and', 'ambulances', 'did', "n't", 'save', 'the', 'most', 'lives', 'after', 'earthquakes', '.']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
#
# 66
# ['Even', 'though', 'The', 'Seventh', 'Man', 'was', 'with', 'K', 'the', 'whole', 'time', ',', 'he', 'did', 'not', 'attempt', 'to', 'help', 'K', 'escape', 'from', 'the', 'colossal', 'waves', '.']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
#
# 67
# ['The', 'Seventh', 'Man', 'was', 'too', 'much', 'of', 'a', 'coward', 'to', 'save', 'K', 'when', 'the', 'time', 'came', '.']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
#
# 68
# ['I', 'told', 'myself', 'to', 'run', 'over', 'to', 'K', ',', 'grab', 'hold', 'of', 'him', ',', 'and', 'get', 'out', 'of', 'there', '.']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
#
# 69
# ['It', 'was', 'the', 'only', 'thing', 'to', 'do', '.']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
#
# 70
# ['I', 'knew', 'that', 'the', 'wave', 'was', 'coming', ',', 'and', 'K.', 'did', "n't", 'know', '.']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'B-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim']
#
# 71
# ['As', 'clearly', 'as', 'I', 'knew', 'what', 'I', 'ought', 'to', 'be', 'doing', ',', 'I', 'found', 'myself', 'running', 'the', 'other', 'way', '-', 'running', 'full', 'speed', 'towards', 'the', 'dyke', ',', 'alone', '.']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['B-claim', 'I-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
#
# 72
# ['(', 'Murakami', '138', ')']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim']
#
# 73
# ['The', 'Seventh', 'Man', 'was', 'debating', 'to', 'save', 'K', ',', 'but', 'he', 'decided', 'to', 'save', 'himself', 'first', '.']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
#
# 74
# ['K', 'was', 'a', 'clueless', 'creature', 'at', 'the', 'time', 'of', 'the', 'incident', ',', 'and', 'it', 'was', 'The', 'Seventh', 'Man', "'s", 'job', 'to', 'make', 'K', 'aware', 'of', 'the', 'deadly', 'waves', 'rushing', 'at', 'them', '.']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
#
# 75
# ['I', 'stood', 'there', ',', 'wondering', 'what', 'to', 'do', '.']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
#
# 76
# ['Should', 'I', 'go', 'down', 'to', 'the', 'beach', '?']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
#
# 77
# ['K.', 'might', 'be', 'down', 'there', 'somewhere', ',', 'buried', 'in', 'the', 'sand', '...']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
#
# 78
# ['But', 'I', 'decided', 'not', 'to', 'leave', 'the', 'dyke', '.']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
#
# 79
# ['(', 'Murakami', '138', ')']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim']
#
# 80
# ['This', 'quote', 'shows', 'The', 'Seventh', 'Man', 'saved', 'his', 'own', 'life', ',', 'costing', 'the', 'life', 'of', 'his', 'best', 'friend', '.']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
#
# 81
# ['Moreover', ',', 'Since', 'The', 'Seventh', 'Man', 'was', 'unable', 'to', 'save', 'K', ',', 'he', 'has', 'lifelong', 'guilt', '.']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
#
# 82
# ['Objective', 'or', 'rational', 'guilt', ',', 'by', 'contrast', '—', 'guilt', 'is', 'fitting', 'to', 'one', "'s", 'actions', '—', 'accurately', 'tracks', 'real', 'wrongdoing', 'or', 'culpability', ':', 'guilt', 'is', 'appropriate', 'because', 'one', 'acted', 'to', 'deliberately', 'harm', 'someone', ',', 'or', 'could', 'have', 'prevented', 'harm', 'and', 'did', 'not', '.']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
#
# 83
# ['(', 'Sherman', '154', ')']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim']
#
# 84
# ['He', 'has', 'this', 'guilt', 'because', 'he', 'has', 'caused', 'real', 'harm', ':', 'not', 'saving', 'K', "'s", 'life', '.']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
#
# 85
# ['But', 'I', 'knew', 'the', 'truth', '.']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
#
# 86
# ['I', 'knew', 'that', 'I', 'could', 'have', 'saved', 'K.', 'if', 'I', 'had', 'tried', '.']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
#
# 87
# ['I', 'probably', 'could', 'have', 'run', 'over', 'and', 'dragged', 'him', 'out', 'of', 'the', 'reach', 'of', 'the', 'wave', '.']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
#
# 88
# ['It', 'would', 'have', 'been', 'close', ',', 'but', 'as', 'I', 'went', 'over', 'the', 'timing', 'of', 'the', 'events', 'in', 'memory', ',', 'it', 'always', 'seemed', 'to', 'me', 'that', 'I', 'could', 'have', 'made', 'it', '.']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
#
# 89
# ['As', 'I', 'said', 'before', ',', 'though', ',', 'overcome', 'with', 'fear', ',', 'I', 'abandoned', 'him', 'there', 'and', 'saved', 'only', 'myself', '.']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
#
# 90
# ['(', 'Murakami', '140', ')']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim']
#
# 91
# ['The', 'Seventh', 'Man', 'himself', 'believed', 'he', 'could', 'have', 'saved', 'K', "'s", 'life', 'after', 'he', 'rethought', 'the', 'situation', '.']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
#
# 92
# ['Lastly', ',', 'The', 'Seventh', 'Man', 'should', "n't", 'forgive', 'himself', 'because', 'he', 'failed', 'to', 'save', 'his', 'best', 'friend', '/', 'neighbor', ',', 'which', 'led', 'to', 'lifelong', 'objective', 'guilt', 'for', 'him', '.']
# ['O-claim', 'O-claim', 'B-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['O-claim', 'O-claim', 'B-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
#
# 93
# ['There', 'were', 'many', 'instances', 'where', 'The', 'Seventh', 'man', 'could', 'have', 'saved', 'K', ',', 'but', 'he', 'let', 'them', 'all', 'slide', 'past', 'him', 'and', 'left', 'K', 'a', 'sitting', 'duck', 'for', 'death', '.']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
#
# 94
# ['The', 'Seventh', 'Man', 'ran', 'away', 'from', 'K', 'because', 'of', 'the', 'overwhelming', 'fear', 'in', 'his', 'veins', '.']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
#
# 95
# ['On', 'July', '30', ',', '1945', ',', 'at', '12:14', 'a.m.', 'a', 'Japanese', 'I-58', 'submarine', 'fired', '6', 'torpedoes', 'at', 'the', 'Indianapolis', ',', 'two', 'of', 'them', 'hit', '.']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim']
#
# 96
# ['Captain', 'Charles', 'B', 'McVay', 'should', 'not', 'have', 'been', 'charged', 'for', 'the', 'sinking', 'of', 'the', 'ship', 'even', 'though', 'it', 'was', 'the', 'Japanese', '.']
# ['B-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim']
# ['B-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim']
#
# 97
# ['This', 'is', 'because', 'the', 'Indianapolis', 'had', 'no', 'safety', 'boats', ',', 'it', 'should', 'have', 'monitored', 'much', 'closer', 'by', 'the', 'military', '.']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'B-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim']
# ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'B-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim']
#
# 98
# ['The', 'Indianapolis', 'should', 'have', 'had', 'better', 'and', 'more', 'lifeboats', '.']
# ['B-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim']
# ['B-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim']
#
# 99
# ['McVay', 'was', 'also', 'a', 'well', '-', 'honored', 'Captain', 'with', 'an', 'incredible', 'crew', 'and', 'would', 'not', 'have', 'put', 'those', 'men', 'through', 'what', 'they', 'went', 'through', 'with', 'the', 'sharks', '.']
# ['B-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim', 'O-claim', 'O-claim', 'B-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim']
# ['B-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim']
#
# 100
# ['The', 'Indianapolis', 'should', 'have', 'had', 'better', 'lifeboats', 'and', 'more', 'to', 'accommodate', 'all', 'the', 'sailors', '.']
# ['B-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim']
# ['B-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim']

# %%
# count short vs long sentences
count_long, count_comma, count_modal, count_multi_claim = 0, 0, 0, 0
for i, (tokens, labels, preds) in enumerate(zip(wm1_tokens[:100], wm1_labels[:100],y_pred[:100])):
    if len(tokens)> 15:
        count_long += 1
    if ',' in tokens:
        count_comma += 1
    modal = [token for token in tokens if token in ['should','would','can','could','must','will']]
    if len(modal)>0:
        count_modal+=1
    if len([label for label in labels if label=='B-claim'])>1:
        count_multi_claim+=1
        print(tokens, '\n', labels, '\n', preds, '\n')
        
print(count_long, count_comma, count_modal, count_multi_claim)
# Out:
# ['Sharks', 'are', "n't", 'monsters', ',', 'in', 'reality', ',', 'they', 'are', 'very', 'special', 'animals', ',', 'what', 'I', 'mean', 'by', 'that', 'is', 'getting', 'rid', 'of', 'them', 'could', 'cause', 'the', 'whole', 'oceans', 'food', 'chain', 'to', 'collapse', '.']
#  ['B-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'B-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'B-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim']
#  ['B-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'B-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim']
#
# ['Many', 'species', 'would', 'be', 'affected', ',', 'many', 'species', 'would', 'end', 'just', 'because', 'of', 'the', 'sharks', '.']
#  ['B-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim', 'B-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim']
#  ['B-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim', 'B-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim']
#
# ['Sharks', 'do', "n't", 'cause', 'as', 'many', 'deaths', 'as', 'you', 'think', ',', 'in', 'reality', ',', 'they', 'save', 'the', 'oceans', 'from', 'a', 'lot', 'of', 'disasters', '.']
#  ['B-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'B-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim']
#  ['O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'O-claim', 'B-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim']
#
# ['McVay', 'was', 'also', 'a', 'well', '-', 'honored', 'Captain', 'with', 'an', 'incredible', 'crew', 'and', 'would', 'not', 'have', 'put', 'those', 'men', 'through', 'what', 'they', 'went', 'through', 'with', 'the', 'sharks', '.']
#  ['B-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim', 'O-claim', 'O-claim', 'B-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim']
#  ['B-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'I-claim', 'O-claim']
#
# 64 47 28 4

# %%
bert_pred = open('/Users/talhindi/Documents/eval_preds_results_wm_argu_bert_train_wm_argu2_gre.txt').readlines()

# %%
sent_ends = [tokens[-2:] for tokens in wm1_tokens[:100]]

# %%
sent, bert_sent = [], []
prev_line, i = bert_pred[0], 0

for line in bert_pred[:1898]:
    
    if prev_line[0] == sent_ends[i][0] and line[0] == sent_ends[i][1]:
        bert_sent.append(sent)
        sent = []
        i +=1
    else:
        sent.append(line.split('\t'))
    
    prev_line = line

len(bert_sent)
# Out:
# 0
